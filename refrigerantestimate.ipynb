# %%
import pandas as pd

refrigerants_data = {
    "Refrigerant Type": ["R-22", "R-134a", "R-410A", "R-32", "R-404A", "R-507", "R-717 (Ammonia)", "R-290 (Propane)", "R-600a (Isobutane)", "R-744 (CO2)"],
    "Applications/Uses": [
        "Residential and commercial air conditioning, refrigeration",
        "Automotive air conditioning, refrigeration, chillers",
        "Residential and commercial air conditioning",
        "Residential air conditioning, heat pumps",
        "Commercial refrigeration",
        "Commercial and industrial refrigeration",
        "Industrial refrigeration, air conditioning, chillers",
        "Domestic refrigeration, small commercial refrigeration",
        "Domestic refrigeration, small air conditioning systems",
        "Commercial refrigeration, heat pumps, air conditioning"
    ],
    "Global Warming Potential (GWP)": [1810, 1430, 2088, 675, 3922, 3985, 0, 3, 3, 1],
    "Other Names": ["HCFC-22", "HFC-134a", "HFC Blend", "HFC-32", "HFC Blend", "HFC Blend", "NH3", "C3H8", "C4H10", "Carbon Dioxide"]
}

df_refrigerants = pd.DataFrame(refrigerants_data)
df_refrigerants
# Out:
#      Refrigerant Type                                  Applications/Uses  \
# 0                R-22  Residential and commercial air conditioning, r...
# 1              R-134a  Automotive air conditioning, refrigeration, ch...
# 2              R-410A        Residential and commercial air conditioning
# 3                R-32           Residential air conditioning, heat pumps
# 4              R-404A                           Commercial refrigeration
# 5               R-507            Commercial and industrial refrigeration
# 6     R-717 (Ammonia)  Industrial refrigeration, air conditioning, ch...
# 7     R-290 (Propane)  Domestic refrigeration, small commercial refri...
# 8  R-600a (Isobutane)  Domestic refrigeration, small air conditioning...
# 9         R-744 (CO2)  Commercial refrigeration, heat pumps, air cond...
#
#    Global Warming Potential (GWP)     Other Names
# 0                            1810         HCFC-22
# 1                            1430        HFC-134a
# ...
